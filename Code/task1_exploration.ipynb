# %%
import torch
for name in ["cells", "lesions", "orgs", "chest", "organs"]:
    d = torch.load(f"../data/{name}.pt", weights_only=True)
    print(f"{name}: {d['train_images'].shape}, labels: {d['train_labels'].shape}")
# Out:
# cells: torch.Size([13671, 3, 64, 64]), labels: torch.Size([13671, 1])
# lesions: torch.Size([8010, 3, 64, 64]), labels: torch.Size([8010, 1])
# orgs: torch.Size([15367, 1, 64, 64]), labels: torch.Size([15367, 1])
# chest: torch.Size([5232, 1, 64, 64]), labels: torch.Size([5232, 1])
# organs: torch.Size([500, 1, 64, 64]), labels: torch.Size([500, 1])

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: ResNet18
# Using activation function: ReLU(inplace=True)
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 0.1953 - Train Acc: 92.33% | Val Loss: 0.2913 - Val Acc: 89.48%
# Epoch [02/20] | Train Loss: 0.0964 - Train Acc: 96.28% | Val Loss: 0.1563 - Val Acc: 93.50%
# Epoch [03/20] | Train Loss: 0.0646 - Train Acc: 97.86% | Val Loss: 0.2050 - Val Acc: 93.12%
# Epoch [04/20] | Train Loss: 0.0458 - Train Acc: 98.19% | Val Loss: 0.9712 - Val Acc: 81.07%
# Epoch [05/20] | Train Loss: 0.0329 - Train Acc: 98.83% | Val Loss: 0.1511 - Val Acc: 94.65%
# Epoch [06/20] | Train Loss: 0.0184 - Train Acc: 99.49% | Val Loss: 0.1318 - Val Acc: 95.41%
# Epoch [07/20] | Train Loss: 0.0135 - Train Acc: 99.62% | Val Loss: 0.1322 - Val Acc: 96.37%
# Epoch [08/20] | Train Loss: 0.0080 - Train Acc: 99.79% | Val Loss: 0.2619 - Val Acc: 93.88%
# ...

# %% [markdown]
# With Data Augmentation

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: ResNet18
# Using activation function: ReLU(inplace=True)
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 0.2340 - Train Acc: 90.25% | Val Loss: 0.1646 - Val Acc: 95.22%
# Epoch [02/20] | Train Loss: 0.1374 - Train Acc: 94.63% | Val Loss: 0.2057 - Val Acc: 92.54%
# Epoch [03/20] | Train Loss: 0.1337 - Train Acc: 95.18% | Val Loss: 0.4767 - Val Acc: 85.09%
# Epoch [04/20] | Train Loss: 0.1160 - Train Acc: 95.46% | Val Loss: 0.2195 - Val Acc: 93.12%
# Epoch [05/20] | Train Loss: 0.1116 - Train Acc: 95.99% | Val Loss: 0.1643 - Val Acc: 94.84%
# Epoch [06/20] | Train Loss: 0.1003 - Train Acc: 96.11% | Val Loss: 0.1407 - Val Acc: 95.98%
# Epoch [07/20] | Train Loss: 0.1060 - Train Acc: 95.99% | Val Loss: 0.3252 - Val Acc: 90.63%
# Epoch [08/20] | Train Loss: 0.0884 - Train Acc: 96.81% | Val Loss: 0.4270 - Val Acc: 87.95%
# ...

# %% [markdown]
# With Scheduler only for chest dataset and Alexnet

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: AlexNet
# /home/k70801/dl_env/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 0.3655 - Train Acc: 81.08% | Val Loss: 0.4295 - Val Acc: 88.72%
# Epoch [02/20] | Train Loss: 0.2070 - Train Acc: 91.97% | Val Loss: 0.2134 - Val Acc: 92.35%
# Epoch [03/20] | Train Loss: 0.1522 - Train Acc: 94.03% | Val Loss: 0.1560 - Val Acc: 94.46%
# Epoch [04/20] | Train Loss: 0.1438 - Train Acc: 94.46% | Val Loss: 0.2519 - Val Acc: 92.73%
# Epoch [05/20] | Train Loss: 0.1415 - Train Acc: 94.54% | Val Loss: 0.1548 - Val Acc: 94.84%
# Epoch [06/20] | Train Loss: 0.1282 - Train Acc: 94.95% | Val Loss: 0.1388 - Val Acc: 95.03%
# ...

# %% [markdown]
# With Scheduler only for chest dataset and Alexnet with val_spli = 0.2

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: AlexNet
# /home/k70801/dl_env/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 0.3860 - Train Acc: 79.36% | Val Loss: 0.2606 - Val Acc: 90.15%
# Epoch [02/20] | Train Loss: 0.2076 - Train Acc: 91.40% | Val Loss: 0.2351 - Val Acc: 90.44%
# Epoch [03/20] | Train Loss: 0.1761 - Train Acc: 93.22% | Val Loss: 0.3146 - Val Acc: 86.90%
# Epoch [04/20] | Train Loss: 0.1515 - Train Acc: 94.27% | Val Loss: 0.1887 - Val Acc: 93.59%
# Epoch [05/20] | Train Loss: 0.1382 - Train Acc: 94.67% | Val Loss: 0.1804 - Val Acc: 94.36%
# Epoch [06/20] | Train Loss: 0.1316 - Train Acc: 95.03% | Val Loss: 0.1824 - Val Acc: 93.79%
# ...

# %% [markdown]
# With Scheduler only for chest dataset and Alexnet with val_spli = 0.2 + batch_soze = 32

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: AlexNet
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 0.3284 - Train Acc: 84.28% | Val Loss: 0.2525 - Val Acc: 89.77%
# Epoch [02/20] | Train Loss: 0.1880 - Train Acc: 92.43% | Val Loss: 0.1692 - Val Acc: 94.07%
# Epoch [03/20] | Train Loss: 0.1651 - Train Acc: 93.60% | Val Loss: 0.1909 - Val Acc: 92.93%
# Epoch [04/20] | Train Loss: 0.1577 - Train Acc: 94.00% | Val Loss: 0.2564 - Val Acc: 89.48%
# Epoch [05/20] | Train Loss: 0.1333 - Train Acc: 95.08% | Val Loss: 0.1440 - Val Acc: 94.93%
# Epoch [06/20] | Train Loss: 0.1340 - Train Acc: 95.03% | Val Loss: 0.1518 - Val Acc: 94.74%
# Epoch [07/20] | Train Loss: 0.1394 - Train Acc: 94.74% | Val Loss: 0.1334 - Val Acc: 95.12%
# Epoch [08/20] | Train Loss: 0.1130 - Train Acc: 95.63% | Val Loss: 0.1115 - Val Acc: 95.98%
# Epoch [09/20] | Train Loss: 0.1042 - Train Acc: 96.13% | Val Loss: 0.1209 - Val Acc: 95.60%
# ...

# %% [markdown]
# With Scheduler only for chest dataset and Alexnet with val_spli = 0.2 + batch_soze = 64 and epoch = 40

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: AlexNet
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/40] | Train Loss: 0.3860 - Train Acc: 79.26% | Val Loss: 0.2626 - Val Acc: 89.67%
# Epoch [02/40] | Train Loss: 0.2074 - Train Acc: 91.45% | Val Loss: 0.2401 - Val Acc: 90.25%
# Epoch [03/40] | Train Loss: 0.1752 - Train Acc: 93.17% | Val Loss: 0.2770 - Val Acc: 89.10%
# Epoch [04/40] | Train Loss: 0.1513 - Train Acc: 94.29% | Val Loss: 0.1885 - Val Acc: 93.31%
# Epoch [05/40] | Train Loss: 0.1376 - Train Acc: 94.70% | Val Loss: 0.1793 - Val Acc: 94.46%
# Epoch [06/40] | Train Loss: 0.1308 - Train Acc: 95.01% | Val Loss: 0.1748 - Val Acc: 93.69%
# Epoch [07/40] | Train Loss: 0.1373 - Train Acc: 94.46% | Val Loss: 0.2562 - Val Acc: 91.40%
# Epoch [08/40] | Train Loss: 0.1154 - Train Acc: 95.68% | Val Loss: 0.1358 - Val Acc: 94.74%
# Epoch [09/40] | Train Loss: 0.1122 - Train Acc: 95.70% | Val Loss: 0.1482 - Val Acc: 94.46%
# ...

# %% [markdown]
# with padding = 0 if kernel size ==1 for VGG16 block

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: VGG16
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 0.2517 - Train Acc: 88.65% | Val Loss: 0.1645 - Val Acc: 95.32%
# Epoch [02/20] | Train Loss: 0.1352 - Train Acc: 94.86% | Val Loss: 0.3532 - Val Acc: 88.53%
# Epoch [03/20] | Train Loss: 0.1184 - Train Acc: 95.58% | Val Loss: 0.1773 - Val Acc: 93.79%
# Epoch [04/20] | Train Loss: 0.1041 - Train Acc: 96.06% | Val Loss: 0.1141 - Val Acc: 95.41%
# Epoch [05/20] | Train Loss: 0.1032 - Train Acc: 96.27% | Val Loss: 0.1382 - Val Acc: 95.60%
# Epoch [06/20] | Train Loss: 0.0892 - Train Acc: 96.87% | Val Loss: 0.1999 - Val Acc: 93.50%
# Epoch [07/20] | Train Loss: 0.0911 - Train Acc: 96.68% | Val Loss: 0.1024 - Val Acc: 96.75%
# Epoch [08/20] | Train Loss: 0.0902 - Train Acc: 96.82% | Val Loss: 0.1194 - Val Acc: 95.89%
# Epoch [09/20] | Train Loss: 0.0777 - Train Acc: 96.97% | Val Loss: 0.1517 - Val Acc: 94.84%
# ...
