# %%
import torch
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_fscore_support
print("All imports OK!")
print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# All imports OK!
# GPU: Tesla V100-PCIE-32GB

# %%
import torch
for name in ["cells", "lesions", "orgs", "chest"]:
    d = torch.load(f"../data/{name}.pt", weights_only=True)
    print(f"{name}: {d['train_images'].shape}, labels: {d['train_labels'].shape}")
# Out:
# cells: torch.Size([13671, 3, 64, 64]), labels: torch.Size([13671, 1])
# lesions: torch.Size([8010, 3, 64, 64]), labels: torch.Size([8010, 1])
# orgs: torch.Size([15367, 1, 64, 64]), labels: torch.Size([15367, 1])
# chest: torch.Size([5232, 1, 64, 64]), labels: torch.Size([5232, 1])

# %% [markdown]
# 190 * 4 * 4

# %%
from train import main
main()
# Out:
# Training executing on device: cuda
#
# Training model: ResNet18
# Using activation function: ReLU(inplace=True)
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 0.2681 - Train Acc: 89.62% | Val Loss: 0.2271 - Val Acc: 91.97%
# Epoch [02/20] | Train Loss: 0.1745 - Train Acc: 93.20% | Val Loss: 0.1643 - Val Acc: 93.12%
# Epoch [03/20] | Train Loss: 0.1315 - Train Acc: 94.88% | Val Loss: 0.1500 - Val Acc: 95.22%
# Epoch [04/20] | Train Loss: 0.1237 - Train Acc: 95.24% | Val Loss: 0.1846 - Val Acc: 92.35%
# Epoch [05/20] | Train Loss: 0.1043 - Train Acc: 95.77% | Val Loss: 0.5210 - Val Acc: 85.85%
# Epoch [06/20] | Train Loss: 0.0932 - Train Acc: 96.64% | Val Loss: 0.1958 - Val Acc: 93.50%
# Epoch [07/20] | Train Loss: 0.0828 - Train Acc: 96.90% | Val Loss: 0.0911 - Val Acc: 95.60%
# Epoch [08/20] | Train Loss: 0.0663 - Train Acc: 97.73% | Val Loss: 0.2103 - Val Acc: 93.50%
# Epoch [09/20] | Train Loss: 0.0709 - Train Acc: 97.39% | Val Loss: 0.5579 - Val Acc: 81.45%
# Epoch [10/20] | Train Loss: 0.0774 - Train Acc: 97.26% | Val Loss: 0.0881 - Val Acc: 96.56%
# Epoch [11/20] | Train Loss: 0.0698 - Train Acc: 97.37% | Val Loss: 0.1100 - Val Acc: 95.41%
# Epoch [12/20] | Train Loss: 0.0554 - Train Acc: 97.81% | Val Loss: 0.0875 - Val Acc: 96.94%
# Epoch [13/20] | Train Loss: 0.0555 - Train Acc: 97.81% | Val Loss: 0.1639 - Val Acc: 94.84%
# Epoch [14/20] | Train Loss: 0.0529 - Train Acc: 97.94% | Val Loss: 0.8344 - Val Acc: 83.17%
# Epoch [15/20] | Train Loss: 0.0580 - Train Acc: 97.71% | Val Loss: 0.2445 - Val Acc: 92.93%
# Epoch [16/20] | Train Loss: 0.0480 - Train Acc: 98.13% | Val Loss: 0.1532 - Val Acc: 95.60%
# Epoch [17/20] | Train Loss: 0.0386 - Train Acc: 98.62% | Val Loss: 1.2614 - Val Acc: 76.10%
# Epoch [18/20] | Train Loss: 0.0322 - Train Acc: 98.96% | Val Loss: 0.2518 - Val Acc: 94.07%
# Epoch [19/20] | Train Loss: 0.0279 - Train Acc: 99.00% | Val Loss: 0.1495 - Val Acc: 95.22%
# Epoch [20/20] | Train Loss: 0.0383 - Train Acc: 98.58% | Val Loss: 2.3365 - Val Acc: 57.36%
# --------------------------------------------------
# Training Complete!
# Loaded best model weights for final evaluation.
#
# ==================================================
# Model: ResNet18 | Dataset

# ==================================================
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 0.9499 - Train Acc: 61.80% | Val Loss: 0.9734 - Val Acc: 63.35%
# Epoch [02/20] | Train Loss: 0.4318 - Train Acc: 83.70% | Val Loss: 0.9768 - Val Acc: 72.93%
# Epoch [03/20] | Train Loss: 0.3355 - Train Acc: 88.25% | Val Loss: 0.3233 - Val Acc: 88.59%
# Epoch [04/20] | Train Loss: 0.2516 - Train Acc: 91.56% | Val Loss: 0.4646 - Val Acc: 84.86%
# Epoch [05/20] | Train Loss: 0.2196 - Train Acc: 93.07% | Val Loss: 0.3080 - Val Acc: 90.42%
# Epoch [06/20] | Train Loss: 0.2051 - Train Acc: 93.60% | Val Loss: 1.7091 - Val Acc: 72.57%
# Epoch [07/20] | Train Loss: 0.1732 - Train Acc: 94.34% | Val Loss: 0.2037 - Val Acc: 93.86%
# Epoch [08/20] | Train Loss: 0.1382 - Train Acc: 95.65% | Val Loss: 0.2143 - Val Acc: 94.15%
# Epoch [09/20] | Train Loss: 0.1869 - Train Acc: 94.25% | Val Loss: 0.3600 - Val Acc: 87.05%
# Epoch [10/20] | Train Loss: 0.1243 - Train Acc: 96.02% | Val Loss: 0.5263 - Val Acc: 85.95%
# Epoch [11/20] | Train Loss: 0.1210 - Train Acc: 96.31% | Val Loss: 2.0353 - Val Acc: 64.96%
# Epoch [12/20] | Train Loss: 0.0965 - Train Acc: 97.04% | Val Loss: 0.2276 - Val Acc: 92.83%
# Epoch [13/20] | Train Loss: 0.1056 - Train Acc: 96.62% | Val Loss: 0.3480 - Val Acc: 90.27%
# Epoch [14/20] | Train Loss: 0.0887 - Train Acc: 97.05% | Val Loss: 0.8684 - Val Acc: 81.93%
# Epoch [15/20] | Train Loss: 0.1196 - Train Acc: 96.33% | Val Loss: 13.8116 - Val Acc: 37.23%
# Epoch [16/20] | Train Loss: 0.1777 - Train Acc: 94.68% | Val Loss: 0.4280 - Val Acc: 86.98%
# Epoch [17/20] | Train Loss: 0.0867 - Train Acc: 97.44% | Val Loss: 0.4642 - Val Acc: 87.78%
# Epoch [18/20] | Train Loss: 0.0848 - Train Acc: 97.33% | Val Loss: 3.0358 - Val Acc: 63.57%
# Epoch [19/20] | Train Loss: 0.1128 - Train Acc: 96.41% | Val Loss: 0.4474 - Val Acc: 88.66%
# Epoch [20/20] | Train Loss: 0.0804 - Train Acc: 97.40% | Val Loss: 0.2129 - Val Acc: 93.71%
# --------------------------------------------------
# Training Complete!
# Loaded best model weights for final evaluation.
#
# ==================================================
# Model: AlexNet | Dataset: cells
# Test Accuracy: 95.62%
# Precision: 95.70%
# Recall: 95.33%
# F1-Score: 95.40%
# ==================================================

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: ResNet18
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/DL_Final_Assignment-main/Code/train.py:61
#      59             print(f"{'='*50}")
#      60 if __name__ == "__main__":
# ---> 61     main()
#
# File ~/DL_Final_Assignment-main/Code/train.py:35, in main()
#      30 channels = dataset_config["CHANNELS"]
#      31 num_classes = dataset_config["NUM_CLASSES"]
# ---> 35 train_loader, val_loader, test_loader = get_loaders( # fixed syntax error
#      36     data=data_name,
#      37     data_path=config["DATA_PATH"],
#      38     batch_size=config["BATCH_SIZE"],
#      39     val_split=config.get("VAL_SPLIT", 0.1) # fixed syntax error
#      40 )
#      42 model_class = getattr(models, config["MODEL"])
#      43 model = model_class(in_channels=channels, num_classes=num_classes).to(device)
#
# File ~/DL_Final_Assignment-main/Code/data.py:12, in get_loaders(data, data_path, batch_size, val_split)
#      10 def get_loaders(data, data_path, batch_size, val_split=0.1):
#      11     d_path = Path(data_path) / f"{data}.pt"  # path issue fixed.....
# ---> 12     data_dict = torch.load(d_path, map_location=torch.device('cpu'), weights_only=False)  # Ensure data is loaded on CPU
#      14     total_samples = data_dict['train_images'].shape[0]
#      15     #shuffling the data to ensure randomness before splitting into train and validation sets
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torch/serialization.py:1500, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1497 if "encoding" not in pickle_load_args:
#    1498     pickle_load_args["encoding"] = "utf-8"
# -> 1500 with _open_file_like(f, "rb") as opened_file:
#    1501     if _is_zipfile(opened_file):
#    1502         # The zipfile reader is going to advance the current file position.
#    1503         # If we want to actually tail call to torch.jit.load, we need to
#    1504         # reset back to the original position.
#    1505         orig_position = opened_file.tell()
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torch/serialization.py:768, in _open_file_like(name_or_buffer, mode)
#     766 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     767     if _is_path(name_or_buffer):
# --> 768         return _open_file(name_or_buffer, mode)
#     769     else:
#     770         if "w" in mode:
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torch/serialization.py:749, in _open_file.__init__(self, name, mode)
#     748 def __init__(self, name: str | os.PathLike[str], mode: str) -> None:
# --> 749     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/chest.pt'

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: ResNet18
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/DL_Final_Assignment-main/Code/train.py:61
#      59             print(f"{'='*50}")
#      60 if __name__ == "__main__":
# ---> 61     main()
#
# File ~/DL_Final_Assignment-main/Code/train.py:35, in main()
#      30 channels = dataset_config["CHANNELS"]
#      31 num_classes = dataset_config["NUM_CLASSES"]
# ---> 35 train_loader, val_loader, test_loader = get_loaders( # fixed syntax error
#      36     data=data_name,
#      37     data_path=config["DATA_PATH"],
#      38     batch_size=config["BATCH_SIZE"],
#      39     val_split=config.get("VAL_SPLIT", 0.1) # fixed syntax error
#      40 )
#      42 model_class = getattr(models, config["MODEL"])
#      43 model = model_class(in_channels=channels, num_classes=num_classes).to(device)
#
# File ~/DL_Final_Assignment-main/Code/data.py:12, in get_loaders(data, data_path, batch_size, val_split)
#      10 def get_loaders(data, data_path, batch_size, val_split=0.1):
#      11     d_path = Path(data_path) / f"{data}.pt"  # path issue fixed.....
# ---> 12     data_dict = torch.load(d_path, map_location=torch.device('cpu'), weights_only=False)  # Ensure data is loaded on CPU
#      14     total_samples = data_dict['train_images'].shape[0]
#      15     #shuffling the data to ensure randomness before splitting into train and validation sets
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torch/serialization.py:1500, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1497 if "encoding" not in pickle_load_args:
#    1498     pickle_load_args["encoding"] = "utf-8"
# -> 1500 with _open_file_like(f, "rb") as opened_file:
#    1501     if _is_zipfile(opened_file):
#    1502         # The zipfile reader is going to advance the current file position.
#    1503         # If we want to actually tail call to torch.jit.load, we need to
#    1504         # reset back to the original position.
#    1505         orig_position = opened_file.tell()
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torch/serialization.py:768, in _open_file_like(name_or_buffer, mode)
#     766 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     767     if _is_path(name_or_buffer):
# --> 768         return _open_file(name_or_buffer, mode)
#     769     else:
#     770         if "w" in mode:
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torch/serialization.py:749, in _open_file.__init__(self, name, mode)
#     748 def __init__(self, name: str | os.PathLike[str], mode: str) -> None:
# --> 749     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/chest.pt'

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: ResNet18
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/DL_Final_Assignment-main/Code/train.py:61
#      59             print(f"{'='*50}")
#      60 if __name__ == "__main__":
# ---> 61     main()
#
# File ~/DL_Final_Assignment-main/Code/train.py:35, in main()
#      30 channels = dataset_config["CHANNELS"]
#      31 num_classes = dataset_config["NUM_CLASSES"]
# ---> 35 train_loader, val_loader, test_loader = get_loaders( # fixed syntax error
#      36     data=data_name,
#      37     data_path=config["DATA_PATH"],
#      38     batch_size=config["BATCH_SIZE"],
#      39     val_split=config.get("VAL_SPLIT", 0.1) # fixed syntax error
#      40 )
#      42 model_class = getattr(models, config["MODEL"])
#      43 model = model_class(in_channels=channels, num_classes=num_classes).to(device)
#
# File ~/DL_Final_Assignment-main/Code/data.py:70, in get_loaders(data, data_path, batch_size, val_split)
#      67         image = self.transform(self.images[idx])
#      68         return image, self.labels[idx]
# ---> 70 train_dataset = AugmentedDataset(train_data, train_labels)
#      71 val_dataset = TensorDataset(val_data, val_labels)
#      72 test_dataset = TensorDataset(test_data, test_labels)
#
# File ~/DL_Final_Assignment-main/Code/data.py:57, in get_loaders.<locals>.AugmentedDataset.__init__(self, images, labels)
#      55 self.images = images
#      56 self.labels = labels
# ---> 57 self.transform = T.Compose([
#      58     T.RandomHorizontalFlip(p=0.5),
#      59     T.RandomRotation(degrees=15),
#      60     T.RandomAffine(degrees=0, translate=(0.1, 0.1)),
#      61 ])
#
# NameError: name 'T' is not defined

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: ResNet18
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/DL_Final_Assignment-main/Code/train.py:61
#      59             print(f"{'='*50}")
#      60 if __name__ == "__main__":
# ---> 61     main()
#
# File ~/DL_Final_Assignment-main/Code/train.py:35, in main()
#      30 channels = dataset_config["CHANNELS"]
#      31 num_classes = dataset_config["NUM_CLASSES"]
# ---> 35 train_loader, val_loader, test_loader = get_loaders( # fixed syntax error
#      36     data=data_name,
#      37     data_path=config["DATA_PATH"],
#      38     batch_size=config["BATCH_SIZE"],
#      39     val_split=config.get("VAL_SPLIT", 0.1) # fixed syntax error
#      40 )
#      42 model_class = getattr(models, config["MODEL"])
#      43 model = model_class(in_channels=channels, num_classes=num_classes).to(device)
#
# File ~/DL_Final_Assignment-main/Code/data.py:70, in get_loaders(data, data_path, batch_size, val_split)
#      67         image = self.transform(self.images[idx])
#      68         return image, self.labels[idx]
# ---> 70 train_dataset = AugmentedDataset(train_data, train_labels)
#      71 val_dataset = TensorDataset(val_data, val_labels)
#      72 test_dataset = TensorDataset(test_data, test_labels)
#
# File ~/DL_Final_Assignment-main/Code/data.py:57, in get_loaders.<locals>.AugmentedDataset.__init__(self, images, labels)
#      55 self.images = images
#      56 self.labels = labels
# ---> 57 self.transform = T.Compose([
#      58     T.RandomHorizontalFlip(p=0.5),
#      59     T.RandomRotation(degrees=15),
#      60     T.RandomAffine(degrees=0, translate=(0.1, 0.1)),
#      61 ])
#
# NameError: name 'T' is not defined

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: ResNet18
# Using activation function: ReLU(inplace=True)
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/DL_Final_Assignment-main/Code/train.py:61
#      59             print(f"{'='*50}")
#      60 if __name__ == "__main__":
# ---> 61     main()
#
# File ~/DL_Final_Assignment-main/Code/train.py:35, in main()
#      30 channels = dataset_config["CHANNELS"]
#      31 num_classes = dataset_config["NUM_CLASSES"]
# ---> 35 train_loader, val_loader, test_loader = get_loaders( # fixed syntax error
#      36     data=data_name,
#      37     data_path=config["DATA_PATH"],
#      38     batch_size=config["BATCH_SIZE"],
#      39     val_split=config.get("VAL_SPLIT", 0.1) # fixed syntax error
#      40 )
#      42 model_class = getattr(models, config["MODEL"])
#      43 model = model_class(in_channels=channels, num_classes=num_classes).to(device)
#
# File ~/DL_Final_Assignment-main/Code/data.py:13, in get_loaders(data, data_path, batch_size, val_split)
#      11 def get_loaders(data, data_path, batch_size, val_split=0.1):
#      12     d_path = Path(data_path) / f"{data}.pt"  # path issue fixed.....
# ---> 13     data_dict = torch.load(d_path, map_location=torch.device('cpu'), weights_only=False)  # Ensure data is loaded on CPU
#      15     total_samples = data_dict['train_images'].shape[0]
#      16     #shuffling the data to ensure randomness before splitting into train and validation sets
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torch/serialization.py:1500, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1497 if "encoding" not in pickle_load_args:
#    1498     pickle_load_args["encoding"] = "utf-8"
# -> 1500 with _open_file_like(f, "rb") as opened_file:
#    1501     if _is_zipfile(opened_file):
#    1502         # The zipfile reader is going to advance the current file position.
#    1503         # If we want to actually tail call to torch.jit.load, we need to
#    1504         # reset back to the original position.
#    1505         orig_position = opened_file.tell()
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torch/serialization.py:768, in _open_file_like(name_or_buffer, mode)
#     766 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     767     if _is_path(name_or_buffer):
# --> 768         return _open_file(name_or_buffer, mode)
#     769     else:
#     770         if "w" in mode:
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torch/serialization.py:749, in _open_file.__init__(self, name, mode)
#     748 def __init__(self, name: str | os.PathLike[str], mode: str) -> None:
# --> 749     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/chest.pt'

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: AlexNet
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/60] | Train Loss: 0.3863 - Train Acc: 79.29% | Val Loss: 0.2637 - Val Acc: 89.20%
# Epoch [02/60] | Train Loss: 0.2076 - Train Acc: 91.45% | Val Loss: 0.2374 - Val Acc: 90.34%
# Epoch [03/60] | Train Loss: 0.1762 - Train Acc: 93.12% | Val Loss: 0.2903 - Val Acc: 88.62%
# Epoch [04/60] | Train Loss: 0.1512 - Train Acc: 94.31% | Val Loss: 0.1857 - Val Acc: 93.69%
# Epoch [05/60] | Train Loss: 0.1384 - Train Acc: 94.74% | Val Loss: 0.1799 - Val Acc: 94.36%
# Epoch [06/60] | Train Loss: 0.1323 - Train Acc: 94.94% | Val Loss: 0.1719 - Val Acc: 93.79%
# Epoch [07/60] | Train Loss: 0.1373 - Train Acc: 94.60% | Val Loss: 0.2350 - Val Acc: 92.16%
# Epoch [08/60] | Train Loss: 0.1157 - Train Acc: 95.65% | Val Loss: 0.1285 - Val Acc: 95.03%
# Epoch [09/60] | Train Loss: 0.1119 - Train Acc: 95.60% | Val Loss: 0.1501 - Val Acc: 94.07%
# Epoch [10/60] | Train Loss: 0.1190 - Train Acc: 95.05% | Val Loss: 0.1230 - Val Acc: 95.03%
# Epoch [11/60] | Train Loss: 0.1099 - Train Acc: 95.75% | Val Loss: 0.1183 - Val Acc: 95.51%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/DL_Final_Assignment-main/Code/train.py:61
#      59             print(f"{'='*50}")
#      60 if __name__ == "__main__":
# ---> 61     main()
#
# File ~/DL_Final_Assignment-main/Code/train.py:50, in main()
#      48 #remooved the dublicate model code for model, criterion and optimizer
#      49 trainer = Trainer(model, criterion, optimizer, device)
# ---> 50 trainer.fit(train_loader, val_loader, epochs=config["EPOCHS"], dataset_name=data_name)
#      52 test_loss, test_accuracy, precision, recall, f1_score = trainer.evaluate(test_loader)
#      53 print(f"\n{'='*50}")
#
# File ~/DL_Final_Assignment-main/Code/fit.py:77, in Trainer.fit(self, train_loader, val_loader, epochs, dataset_name)
#      74 train_losses, val_losses = [], []
#      76 for epoch in range(epochs):
# ---> 77     train_loss, train_acc = self.train_one_epoch(train_loader)
#      78     val_loss, val_acc, val_prec, val_rec, val_f1 = self.evaluate(val_loader)
#      80     train_losses.append(train_loss) #tracking the train loss for plotting
#
# File ~/DL_Final_Assignment-main/Code/fit.py:23, in Trainer.train_one_epoch(self, dataloader)
#      20 running_loss = 0.0
#      21 correct, total = 0, 0  # changed the variable name from sum to total to avoid shadowing built-in sum function
# ---> 23 for images, labels in dataloader:
#      24     images, labels = images.to(self.device), labels.to(self.device)
#      25     self.optimizer.zero_grad() # added zero_grad() to clear gradients before backpropagation
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torch/utils/data/dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torch/utils/data/dataloader.py:801, in _SingleProcessDataLoaderIter._next_data(self)
#     799 def _next_data(self):
#     800     index = self._next_index()  # may raise StopIteration
# --> 801     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     802     if self._pin_memory:
#     803         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52         data = self.dataset.__getitems__(possibly_batched_index)
#      53     else:
# ---> 54         data = [self.dataset[idx] for idx in possibly_batched_index]
#      55 else:
#      56     data = self.dataset[possibly_batched_index]
#
# File ~/DL_Final_Assignment-main/Code/data.py:68, in get_loaders.<locals>.AugmentedDataset.__getitem__(self, idx)
#      67 def __getitem__(self, idx):
# ---> 68     image = self.transform(self.images[idx])
#      69     return image, self.labels[idx]
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torchvision/transforms/transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torchvision/transforms/transforms.py:1537, in RandomAffine.forward(self, img)
#    1533 img_size = [width, height]  # flip for keeping BC on get_params call
#    1535 ret = self.get_params(self.degrees, self.translate, self.scale, self.shear, img_size)
# -> 1537 return F.affine(img, *ret, interpolation=self.interpolation, fill=fill, center=self.center)
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torchvision/transforms/functional.py:1238, in affine(img, angle, translate, scale, shear, interpolation, fill, center)
#    1236 translate_f = [1.0 * t for t in translate]
#    1237 matrix = _get_inverse_affine_matrix(center_f, angle, translate_f, scale, shear)
# -> 1238 return F_t.affine(img, matrix=matrix, interpolation=interpolation.value, fill=fill)
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torchvision/transforms/_functional_tensor.py:617, in affine(img, matrix, interpolation, fill)
#     615 shape = img.shape
#     616 # grid will be generated on the same device as theta and img
# --> 617 grid = _gen_affine_grid(theta, w=shape[-1], h=shape[-2], ow=shape[-1], oh=shape[-2])
#     618 return _apply_grid_transform(img, grid, interpolation, fill=fill)
#
# File /apps/jupyterhub/jh5.4.4-py3.12/envs/pytorch-2.10.0/lib/python3.12/site-packages/torchvision/transforms/_functional_tensor.py:601, in _gen_affine_grid(theta, w, h, ow, oh)
#     598 base_grid[..., 2].fill_(1)
#     600 rescaled_theta = theta.transpose(1, 2) / torch.tensor([0.5 * w, 0.5 * h], dtype=theta.dtype, device=theta.device)
# --> 601 output_grid = base_grid.view(1, oh * ow, 3).bmm(rescaled_theta)
#     602 return output_grid.view(1, oh, ow, 2)
#
# KeyboardInterrupt:

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: AlexNet
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 0.3864 - Train Acc: 79.31% | Val Loss: 0.2650 - Val Acc: 89.48%
# Epoch [02/20] | Train Loss: 0.2081 - Train Acc: 91.45% | Val Loss: 0.2416 - Val Acc: 90.25%
# Epoch [03/20] | Train Loss: 0.1763 - Train Acc: 93.22% | Val Loss: 0.3023 - Val Acc: 87.67%
# Epoch [04/20] | Train Loss: 0.1510 - Train Acc: 94.27% | Val Loss: 0.1928 - Val Acc: 93.12%
# Epoch [05/20] | Train Loss: 0.1375 - Train Acc: 94.79% | Val Loss: 0.1756 - Val Acc: 94.46%
# Epoch [06/20] | Train Loss: 0.1317 - Train Acc: 94.96% | Val Loss: 0.1762 - Val Acc: 93.79%
# Epoch [07/20] | Train Loss: 0.1370 - Train Acc: 94.62% | Val Loss: 0.2556 - Val Acc: 91.40%
# Epoch [08/20] | Train Loss: 0.1157 - Train Acc: 95.48% | Val Loss: 0.1300 - Val Acc: 95.03%
# Epoch [09/20] | Train Loss: 0.1116 - Train Acc: 95.68% | Val Loss: 0.1537 - Val Acc: 93.69%
# Epoch [10/20] | Train Loss: 0.1188 - Train Acc: 95.13% | Val Loss: 0.1184 - Val Acc: 95.22%
# Epoch [11/20] | Train Loss: 0.1101 - Train Acc: 95.65% | Val Loss: 0.1203 - Val Acc: 95.60%
# Epoch [12/20] | Train Loss: 0.1065 - Train Acc: 95.91% | Val Loss: 0.2878 - Val Acc: 89.58%
# Epoch [13/20] | Train Loss: 0.1019 - Train Acc: 95.94% | Val Loss: 0.1651 - Val Acc: 95.12%
# Epoch [14/20] | Train Loss: 0.1057 - Train Acc: 95.87% | Val Loss: 0.1390 - Val Acc: 95.22%
# Epoch [15/20] | Train Loss: 0.0914 - Train Acc: 96.39% | Val Loss: 0.1279 - Val Acc: 96.27%
# Epoch [16/20] | Train Loss: 0.0872 - Train Acc: 96.54% | Val Loss: 0.1551 - Val Acc: 95.89%
# Epoch [17/20] | Train Loss: 0.0939 - Train Acc: 96.94% | Val Loss: 0.1095 - Val Acc: 96.65%
# Epoch [18/20] | Train Loss: 0.0802 - Train Acc: 97.40% | Val Loss: 0.1449 - Val Acc: 94.17%
# Epoch [19/20] | Train Loss: 0.0833 - Train Acc: 96.89% | Val Loss: 0.1002 - Val Acc: 95.89%
# Epoch [20/20] | Train Loss: 0.0844 - Train Acc: 96.89% | Val Loss: 0.1053 - Val Acc: 97.04%
# --------------------------------------------------
# Training Complete!
# Loaded best model weights for final evaluation.
# ==================================================
# Model: AlexNet | Dataset: chest
# Test Accuracy: 80.45%
# Precision: 88.09%
# Recall: 73.93%
# F1-Score: 75.61%
# ==================================================

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model
# Epoch [20/30] | Train Loss: 0.0776 - Train Acc: 96.82% | Val Loss: 0.1037 - Val Acc: 96.37%
# Epoch [21/30] | Train Loss: 0.0727 - Train Acc: 97.28% | Val Loss: 0.0833 - Val Acc: 96.94%
# Epoch [22/30] | Train Loss: 0.0729 - Train Acc: 97.04% | Val Loss: 0.0958 - Val Acc: 96.65%
# Epoch [23/30] | Train Loss: 0.0746 - Train Acc: 97.25% | Val Loss: 0.1469 - Val Acc: 95.51%
# Epoch [24/30] | Train Loss: 0.0704 - Train Acc: 97.30% | Val Loss: 0.1360 - Val Acc: 95.79%
# Epoch [25/30] | Train Loss: 0.0887 - Train Acc: 96.68% | Val Loss: 0.0868 - Val Acc: 96.08%
# Epoch [26/30] | Train Loss: 0.0763 - Train Acc: 97.11% | Val Loss: 0.0772 - Val Acc: 97.04%
# Epoch [27/30] | Train Loss: 0.0657 - Train Acc: 97.66% | Val Loss: 0.0985 - Val Acc: 96.65%
# Epoch [28/30] | Train Loss: 0.0745 - Train Acc: 97.37% | Val Loss: 0.1024 - Val Acc: 96.75%
# Epoch [29/30] | Train Loss: 0.0668 - Train Acc: 97.52% | Val Loss: 0.0831 - Val Acc: 97.23%
# Epoch [30/30] | Train Loss: 0.0648 - Train Acc: 97.59% | Val Loss: 0.0925 - Val Acc: 96.94%
# --------------------------------------------------
# Training Complete!
# Loaded best model weights for final evaluation.
# ==================================================
# Model: AlexNet | Dataset: chest
# Test Accuracy: 84.29%
# Precision: 89.37%
# Recall: 79.23%
# F1-Score: 81.29%
# ==================================================

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: AlexNet
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/DL_Final_Assignment-main/Code/train.py:63
#      61             print(f"{'='*50}")
#      62 if __name__ == "__main__":
# ---> 63     main()
#
# File ~/DL_Final_Assignment-main/Code/train.py:51, in main()
#      47 scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.5)
#      50 #remooved the dublicate model code for model, criterion and optimizer
# ---> 51 trainer = Trainer(model, criterion, optimizer, device, scheduler)
#      52 trainer.fit(train_loader, val_loader, epochs=config["EPOCHS"], dataset_name=data_name)
#      54 test_loss, test_accuracy, precision, recall, f1_score = trainer.evaluate(test_loader)
#
# TypeError: Trainer.__init__() takes 5 positional arguments but 6 were given

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: AlexNet
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/30] | Train Loss: 0.3863 - Train Acc: 79.29% | Val Loss: 0.2643 - Val Acc: 89.10%
# Epoch [02/30] | Train Loss: 0.2077 - Train Acc: 91.50% | Val Loss: 0.2411 - Val Acc: 90.25%
# Epoch [03/30] | Train Loss: 0.1763 - Train Acc: 93.22% | Val Loss: 0.3073 - Val Acc: 87.38%
# Epoch [04/30] | Train Loss: 0.1514 - Train Acc: 94.24% | Val Loss: 0.1878 - Val Acc: 93.69%
# Epoch [05/30] | Train Loss: 0.1385 - Train Acc: 94.74% | Val Loss: 0.1718 - Val Acc: 94.26%
# Epoch [06/30] | Train Loss: 0.1307 - Train Acc: 94.96% | Val Loss: 0.1709 - Val Acc: 93.69%
# Epoch [07/30] | Train Loss: 0.1367 - Train Acc: 94.51% | Val Loss: 0.2537 - Val Acc: 91.49%
# Epoch [08/30] | Train Loss: 0.1152 - Train Acc: 95.65% | Val Loss: 0.1274 - Val Acc: 95.22%
# Epoch [09/30] | Train Loss: 0.1114 - Train Acc: 95.72% | Val Loss: 0.1473 - Val Acc: 94.55%
# Epoch [10/30] | Train Loss: 0.1177 - Train Acc: 95.17% | Val Loss: 0.1199 - Val Acc: 95.12%
# Epoch [11/30] | Train Loss: 0.1086 - Train Acc: 95.82% | Val Loss: 0.1168 - Val Acc: 95.70%
# Epoch [12/30] | Train Loss: 0.1055 - Train Acc: 96.08% | Val Loss: 0.2776 - Val Acc: 89.48%
# Epoch [13/30] | Train Loss: 0.1001 - Train Acc: 96.08% | Val Loss: 0.1596 - Val Acc: 95.03%
# Epoch [14/30] | Train Loss: 0.1011 - Train Acc: 96.01% | Val Loss: 0.1347 - Val Acc: 95.22%
# Epoch [15/30] | Train Loss: 0.0916 - Train Acc: 96.49% | Val Loss: 0.1182 - Val Acc: 96.56%
# Epoch [16/30] | Train Loss: 0.0866 - Train Acc: 96.68% | Val Loss: 0.1573 - Val Acc: 96.08%
# Epoch [17/30] | Train Loss: 0.0921 - Train Acc: 96.89% | Val Loss: 0.1099 - Val Acc: 96.75%
# Epoch [18/30] | Train Loss: 0.0805 - Train Acc: 97.52% | Val Loss: 0.1486 - Val Acc: 93.98%
# Epoch [19/30] | Train Loss: 0.0823 - Train Acc: 96.80% | Val Loss: 0.0989 - Val Acc: 96.18%
# Epoch [20/30] | Train Loss: 0.0826 - Train Acc: 96.89% | Val Loss: 0.1020 - Val Acc: 96.65%
# Epoch [21/30] | Train Loss: 0.0722 - Train Acc: 97.23% | Val Loss: 0.1018 - Val Acc: 95.98%
# Epoch [22/30] | Train Loss: 0.0746 - Train Acc: 97.09% | Val Loss: 0.1315 - Val Acc: 95.51%
# Epoch [23/30] | Train Loss: 0.0785 - Train Acc: 97.44% | Val Loss: 0.1073 - Val Acc: 96.75%
# Epoch [24/30] | Train Loss: 0.0689 - Train Acc: 97.37% | Val Loss: 0.0882 - Val Acc: 97.04%
# Epoch [25/30] | Train Loss: 0.0910 - Train Acc: 96.66% | Val Loss: 0.0889 - Val Acc: 96.37%
# Epoch [26/30] | Train Loss: 0.0738 - Train Acc: 97.20% | Val Loss: 0.0854 - Val Acc: 96.94%
# Epoch [27/30] | Train Loss: 0.0743 - Train Acc: 97.44% | Val Loss: 0.1038 - Val Acc: 96.37%
# Epoch [28/30] | Train Loss: 0.0718 - Train Acc: 97.59% | Val Loss: 0.0848 - Val Acc: 96.85%
# Epoch [29/30] | Train Loss: 0.0746 - Train Acc: 97.30% | Val Loss: 0.1032 - Val Acc: 95.70%
# Epoch [30/30] | Train Loss: 0.0628 - Train Acc: 97.73% | Val Loss: 0.0836 - Val Acc: 97.23%
# --------------------------------------------------
# Training Complete!
# Loaded best model weights for final evaluation.
# ==================================================
# Model: AlexNet | Dataset: chest
# Test Accuracy: 84.13%
# Precision: 89.00%
# Recall: 79.10%
# F1-Score: 81.13%
# ==================================================
