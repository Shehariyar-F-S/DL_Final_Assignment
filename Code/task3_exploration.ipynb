# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: ResNet18
# Using activation function: ReLU(inplace=True)
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 2.0411 - Train Acc: 29.00% | Val Loss: 2.9571 - Val Acc: 8.00%
# Epoch [02/20] | Train Loss: 1.5087 - Train Acc: 45.75% | Val Loss: 5.1550 - Val Acc: 8.00%
# Epoch [03/20] | Train Loss: 1.3342 - Train Acc: 50.75% | Val Loss: 3.5877 - Val Acc: 14.00%
# Epoch [04/20] | Train Loss: 1.2596 - Train Acc: 53.75% | Val Loss: 1.5412 - Val Acc: 47.00%
# Epoch [05/20] | Train Loss: 1.2111 - Train Acc: 55.25% | Val Loss: 1.5860 - Val Acc: 38.00%
# Epoch [06/20] | Train Loss: 1.0429 - Train Acc: 60.75% | Val Loss: 1.1466 - Val Acc: 59.00%
# Epoch [07/20] | Train Loss: 1.0917 - Train Acc: 58.50% | Val Loss: 1.5842 - Val Acc: 34.00%
# Epoch [08/20] | Train Loss: 1.0679 - Train Acc: 61.75% | Val Loss: 1.0273 - Val Acc: 61.00%
# ...

# %% [markdown]
# with label smoothing

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: ResNet18
# Using activation function: ReLU(inplace=True)
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 2.1462 - Train Acc: 28.75% | Val Loss: 2.8689 - Val Acc: 8.00%
# Epoch [02/20] | Train Loss: 1.7441 - Train Acc: 45.25% | Val Loss: 4.8368 - Val Acc: 8.00%
# Epoch [03/20] | Train Loss: 1.6126 - Train Acc: 51.25% | Val Loss: 3.5958 - Val Acc: 14.00%
# Epoch [04/20] | Train Loss: 1.5602 - Train Acc: 51.75% | Val Loss: 1.7558 - Val Acc: 47.00%
# Epoch [05/20] | Train Loss: 1.4952 - Train Acc: 56.50% | Val Loss: 1.6433 - Val Acc: 47.00%
# Epoch [06/20] | Train Loss: 1.3816 - Train Acc: 64.25% | Val Loss: 1.4666 - Val Acc: 55.00%
# Epoch [07/20] | Train Loss: 1.4100 - Train Acc: 58.25% | Val Loss: 1.8580 - Val Acc: 35.00%
# Epoch [08/20] | Train Loss: 1.4028 - Train Acc: 59.50% | Val Loss: 1.3685 - Val Acc: 63.00%
# ...

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: ResNet18
#
# [PART 3 - A] Training ResNet18 from SCRATCH on 'organs'...
# Using activation function: ReLU(inplace=True)
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 2.0403 - Train Acc: 28.25% | Val Loss: 2.9619 - Val Acc: 8.00%
# Epoch [02/20] | Train Loss: 1.5039 - Train Acc: 46.75% | Val Loss: 5.3375 - Val Acc: 8.00%
# Epoch [03/20] | Train Loss: 1.3384 - Train Acc: 51.75% | Val Loss: 3.6567 - Val Acc: 14.00%
# Epoch [04/20] | Train Loss: 1.2638 - Train Acc: 53.75% | Val Loss: 1.5450 - Val Acc: 48.00%
# Epoch [05/20] | Train Loss: 1.1912 - Train Acc: 57.00% | Val Loss: 1.7743 - Val Acc: 34.00%
# Epoch [06/20] | Train Loss: 1.0355 - Train Acc: 61.00% | Val Loss: 1.0550 - Val Acc: 60.00%
# Epoch [07/20] | Train Loss: 1.0851 - Train Acc: 59.50% | Val Loss: 1.5140 - Val Acc: 40.00%
# ...

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: ResNet18
# Using activation function: ReLU(inplace=True)
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 1.1954 - Train Acc: 70.63% | Val Loss: 0.9781 - Val Acc: 81.42%
# Epoch [02/20] | Train Loss: 0.9058 - Train Acc: 84.88% | Val Loss: 0.7819 - Val Acc: 90.95%
# Epoch [03/20] | Train Loss: 0.8419 - Train Acc: 88.09% | Val Loss: 0.7492 - Val Acc: 92.29%
# Epoch [04/20] | Train Loss: 0.7927 - Train Acc: 90.12% | Val Loss: 0.7608 - Val Acc: 91.93%
# Epoch [05/20] | Train Loss: 0.7663 - Train Acc: 91.41% | Val Loss: 0.7270 - Val Acc: 92.81%
# Epoch [06/20] | Train Loss: 0.7493 - Train Acc: 92.04% | Val Loss: 0.7211 - Val Acc: 92.87%
# Epoch [07/20] | Train Loss: 0.7257 - Train Acc: 92.99% | Val Loss: 0.6863 - Val Acc: 95.09%
# Epoch [08/20] | Train Loss: 0.7113 - Train Acc: 93.55% | Val Loss: 0.6605 - Val Acc: 96.29%
# ...

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: ResNet18
# Using activation function: ReLU(inplace=True)
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 1.1972 - Train Acc: 70.76% | Val Loss: 0.9315 - Val Acc: 82.98%
# Epoch [02/20] | Train Loss: 0.9113 - Train Acc: 84.89% | Val Loss: 0.7765 - Val Acc: 91.54%
# Epoch [03/20] | Train Loss: 0.8450 - Train Acc: 87.97% | Val Loss: 0.7440 - Val Acc: 92.84%
# Epoch [04/20] | Train Loss: 0.7949 - Train Acc: 90.01% | Val Loss: 0.7368 - Val Acc: 92.81%
# Epoch [05/20] | Train Loss: 0.7685 - Train Acc: 91.25% | Val Loss: 0.7395 - Val Acc: 92.35%
# Epoch [06/20] | Train Loss: 0.7497 - Train Acc: 92.02% | Val Loss: 0.7298 - Val Acc: 92.84%
# Epoch [07/20] | Train Loss: 0.7265 - Train Acc: 92.92% | Val Loss: 0.6848 - Val Acc: 95.51%
# Epoch [08/20] | Train Loss: 0.7115 - Train Acc: 93.67% | Val Loss: 0.6599 - Val Acc: 96.45%
# ...
