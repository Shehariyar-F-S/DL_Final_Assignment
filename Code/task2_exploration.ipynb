# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: ResNet18
# Using activation function: ReLU(inplace=True)
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 0.2153 - Train Acc: 91.23% | Val Loss: 0.8948 - Val Acc: 78.30%
# Epoch [02/20] | Train Loss: 0.1584 - Train Acc: 93.76% | Val Loss: 0.2884 - Val Acc: 90.15%
# Epoch [03/20] | Train Loss: 0.1231 - Train Acc: 95.60% | Val Loss: 0.3519 - Val Acc: 86.71%
# Epoch [04/20] | Train Loss: 0.1241 - Train Acc: 95.39% | Val Loss: 0.1655 - Val Acc: 95.98%
# Epoch [05/20] | Train Loss: 0.1077 - Train Acc: 95.99% | Val Loss: 0.2820 - Val Acc: 89.20%
# Epoch [06/20] | Train Loss: 0.1032 - Train Acc: 96.06% | Val Loss: 0.1616 - Val Acc: 95.12%
# Epoch [07/20] | Train Loss: 0.0970 - Train Acc: 96.44% | Val Loss: 0.1356 - Val Acc: 95.03%
# Epoch [08/20] | Train Loss: 0.0919 - Train Acc: 96.68% | Val Loss: 0.6643 - Val Acc: 84.80%
# ...

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: GreenResNet18
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 0.2687 - Train Acc: 87.63% | Val Loss: 0.4433 - Val Acc: 84.70%
# Epoch [02/20] | Train Loss: 0.1549 - Train Acc: 93.79% | Val Loss: 0.3345 - Val Acc: 88.72%
# Epoch [03/20] | Train Loss: 0.1240 - Train Acc: 95.22% | Val Loss: 0.3592 - Val Acc: 86.71%
# Epoch [04/20] | Train Loss: 0.1264 - Train Acc: 95.01% | Val Loss: 0.2251 - Val Acc: 91.78%
# Epoch [05/20] | Train Loss: 0.1084 - Train Acc: 95.89% | Val Loss: 0.1717 - Val Acc: 94.07%
# Epoch [06/20] | Train Loss: 0.1134 - Train Acc: 95.82% | Val Loss: 0.1207 - Val Acc: 95.79%
# Epoch [07/20] | Train Loss: 0.0946 - Train Acc: 96.32% | Val Loss: 0.1240 - Val Acc: 96.56%
# Epoch [08/20] | Train Loss: 0.0960 - Train Acc: 96.58% | Val Loss: 0.1982 - Val Acc: 93.31%
# ...

# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: GreenResNet18
#
#  Starting Training Routine...
# --------------------------------------------------
# Epoch [01/20] | Train Loss: 0.2689 - Train Acc: 87.67% | Val Loss: 0.3999 - Val Acc: 86.23%
# Epoch [02/20] | Train Loss: 0.1538 - Train Acc: 93.67% | Val Loss: 0.3263 - Val Acc: 88.72%
# Epoch [03/20] | Train Loss: 0.1240 - Train Acc: 95.10% | Val Loss: 0.4153 - Val Acc: 85.95%
# Epoch [04/20] | Train Loss: 0.1251 - Train Acc: 94.98% | Val Loss: 0.1718 - Val Acc: 93.31%
# Epoch [05/20] | Train Loss: 0.1085 - Train Acc: 95.94% | Val Loss: 0.1362 - Val Acc: 96.18%
# Epoch [06/20] | Train Loss: 0.1110 - Train Acc: 95.77% | Val Loss: 0.2333 - Val Acc: 91.97%
# Epoch [07/20] | Train Loss: 0.0974 - Train Acc: 96.27% | Val Loss: 0.1634 - Val Acc: 95.32%
# Epoch [08/20] | Train Loss: 0.0970 - Train Acc: 96.44% | Val Loss: 0.2430 - Val Acc: 91.87%
# ...
