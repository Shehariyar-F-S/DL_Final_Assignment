# %%
# %run train.py
# Out:
# Training executing on device: cuda
#
# Training model: ResNet18
# Using activation function: ReLU(inplace=True)
#
#  Starting Training Routine...
# --------------------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/DL_Final_Assignment/Code/train.py:60
#      57             print(f"{'='*50}")
#      59 if __name__ == "__main__":
# ---> 60     main()
#
# File ~/DL_Final_Assignment/Code/train.py:46, in main()
#      42 scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.5,)  # fix: added a learning rate scheduler to reduce the learning rate on plateau
#      45 trainer = Trainer(model, criterion, optimizer, device, scheduler)
# ---> 46 trainer.fit(train_loader, val_loader, epochs=config["EPOCHS"], dataset_name=data_name, )  # fix: added dataset_name parameter to the fit method for better logging
# ...
